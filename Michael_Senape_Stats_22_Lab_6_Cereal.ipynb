# %% [markdown]
# <a href="https://colab.research.google.com/github/mikesenape/labs-4-9/blob/main/Michael_Senape_Stats_22_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %% [markdown]
# import functions as nicknames

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7eff652b64f0>)

# %% [markdown]
# insert ceareal products url

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %% [markdown]
# insert cereal_data as our data

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %% [markdown]
# inserted the data splitting into certain categories

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# portrayed the data showing calorie information and other characteristics

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %% [markdown]
# inserted a equation find the mean of sugars in all cereal

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %% [markdown]
# showed calories and sugars of cereal

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# described the data in more detail

# %%
cereal_data[["calories", "sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %% [markdown]
# portrayed the data of each cereals calories and sugars side by side

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

# %% [markdown]
# inserted the sugars and calories on the chart

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %% [markdown]
# cused the plot graph to add fat instead of sugars

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %% [markdown]
# inserted sugars and carbo here to portray the data

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %% [markdown]
# portrayed the sugars and vitamis in this chart

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %% [markdown]
# gave x the vlaue of sugars and y the value of calories

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %% [markdown]
# inserted a linear regression model

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %% [markdown]
# made the model fit for (X,Y)

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
# plotted the calories and sugars and added a mean line of claories and sugars

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %% [markdown]
# inserted a linspace from 0 to 10 to 50

# %%
noise = 10 * np.random.randn(50,)

# %% [markdown]
# inserted a noise of 10 and a random number from x =50

# %%
y = 3 * x + 7 + noise

# %% [markdown]
# inserted a y= mx +b equation

# %%
plt.plot(x,y,'.');

# %% [markdown]
# plotted the data on a graph

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %% [markdown]
# inserted a guess function run with our data to test how close the system could get

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %% [markdown]
# changed the guess numbers and saw how the data changed

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %% [markdown]
# another example

# %%
loss = np.sum((y_guess - y)**2)

# %% [markdown]
# insert the loss function

# %%
loss
# Out:
# 4961.444159301534

# %% [markdown]
# test the loss

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 441850.3909276445 -10.0 -10.0
# 423454.263576075 -10.0 -7.777777777777778
# 405551.9633849993 -10.0 -5.555555555555555
# 388143.4903544175 -10.0 -3.333333333333333
# 371228.84448432946 -10.0 -1.1111111111111107
# 354808.02577473514 -10.0 1.1111111111111107
# 338881.0342256348 -10.0 3.333333333333334
# 323447.8698370283 -10.0 5.555555555555557
# 308508.5326089156 -10.0 7.777777777777779
# 294063.0225412966 -10.0 10.0
# 329863.88764830003 -7.777777777777778 -10.0
# 313936.89609919966 -7.777777777777778 -7.777777777777778
# 298503.73171059316 -7.777777777777778 -5.555555555555555
# 283564.39448248036 -7.777777777777778 -3.333333333333333
# 269118.88441486156 -7.777777777777778 -1.1111111111111107
# 255167.20150773643 -7.777777777777778 1.1111111111111107
# 241709.3457611052 -7.777777777777778 3.333333333333334
# 228745.31717496776 -7.777777777777778 5.555555555555557
# 216275.11574932418 -7.777777777777778 7.777777777777779
# 204298.74148417442 -7.777777777777778 10.0
# ...

# %% [markdown]
# insert loss to the guess function and see the variety of accuracy across the couple times it ran

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 96965.99580179735 -3.6842105263157894 5.789473684210526
# 93176.6329227375 -3.6842105263157894 6.842105263157894
# 89498.07336777734 -3.6842105263157894 7.894736842105264
# 85930.31713691696 -3.6842105263157894 8.94736842105263
# 82473.36423015624 -3.6842105263157894 10.0
# 79347.05195483517 -2.6315789473684212 3.6842105263157894
# 75890.09904807448 -2.6315789473684212 4.7368421052631575
# 72543.94946541352 -2.6315789473684212 5.789473684210526
# 69308.60320685228 -2.6315789473684212 6.842105263157894
# 66184.06027239075 -2.6315789473684212 7.894736842105264
# 63170.320662028964 -2.6315789473684212 8.94736842105263
# 60267.38437576687 -2.6315789473684212 10.0
# 57548.10471958763 -1.578947368421053 3.6842105263157894
# 54645.16843332556 -1.578947368421053 4.7368421052631575
# 51853.03547116322 -1.578947368421053 5.789473684210526
# 49171.70583310058 -1.578947368421053 6.842105263157894
# 46601.17951913768 -1.578947368421053 7.894736842105264
# ...

# %% [markdown]
# insert the best loss into the equation to show us the best guesses most accurate to the data
